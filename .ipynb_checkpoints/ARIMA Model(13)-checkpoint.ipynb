# %%
# !pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.0.4-cp39-cp39-win_amd64.whl (614 kB)
#      ---------------------------------------- 0.0/615.0 kB ? eta -:--:--
#      --------------------- ---------------- 348.2/615.0 kB 7.3 MB/s eta 0:00:01
#      -------------------------------------- 615.0/615.0 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: urllib3 in d:\ananconda\envs\myenv\lib\site-packages (from pmdarima) (1.26.18)
# Requirement already satisfied: pandas>=0.19 in d:\ananconda\envs\myenv\lib\site-packages (from pmdarima) (2.0.1)
# Collecting Cython!=0.29.18,!=0.29.31,>=0.29
#   Downloading Cython-3.0.5-cp39-cp39-win_amd64.whl (2.8 MB)
#      ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#      ------- -------------------------------- 0.5/2.8 MB 16.5 MB/s eta 0:00:01
#      --------------- ------------------------ 1.1/2.8 MB 13.9 MB/s eta 0:00:01
#      ------------------------- -------------- 1.8/2.8 MB 12.3 MB/s eta 0:00:01
#      ---------------------------------- ----- 2.4/2.8 MB 13.7 MB/s eta 0:00:01
#      ------------------------------------ --- 2.5/2.8 MB 13.3 MB/s eta 0:00:01
#      ---------------------------------------  2.8/2.8 MB 11.1 MB/s eta 0:00:01
#      ---------------------------------------- 2.8/2.8 MB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.2 in d:\ananconda\envs\myenv\lib\site-packages (from pmdarima) (1.24.4)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in d:\ananconda\envs\myenv\lib\site-packages (from pmdarima) (66.0.0)
# Requirement already satisfied: joblib>=0.11 in d:\ananconda\envs\myenv\lib\site-packages (from pmdarima) (1.2.0)
# Requirement already satisfied: packaging>=17.1 in d:\ananconda\envs\myenv\lib\site-packages (from pmdarima) (23.0)
# Requirement already satisfied: scikit-learn>=0.22 in d:\ananconda\envs\myenv\lib\site-packages (from pmdarima) (1.1.1)
# Requirement already satisfied: statsmodels>=0.13.2 in d:\ananconda\envs\myenv\lib\site-packages (from pmdarima) (0.14.0)
# Requirement already satisfied: scipy>=1.3.2 in d:\ananconda\envs\myenv\lib\site-packages (from pmdarima) (1.10.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\ananconda\envs\myenv\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in d:\ananconda\envs\myenv\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in d:\ananconda\envs\myenv\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\ananconda\envs\myenv\lib\site-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in d:\ananconda\envs\myenv\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: six in c:\users\swanand\appdata\roaming\python\python39\site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.15.0)
# Installing collected packages: Cython, pmdarima
# Successfully installed Cython-3.0.5 pmdarima-2.0.4

# %%
import os
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from pmdarima.arima import auto_arima
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

# %%
data = pd.read_csv('Stock_Prices.csv')
data['Date'] = pd.to_datetime(data['Date'], format='%d-%m-%Y')  # Correct date format
data.set_index('Date', inplace=True)

# %%
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Date')
plt.ylabel('Close Prices')
plt.plot(data['Close'])
plt.title('closing price')
plt.show()

# %%
df_close = data['Close']
df_close.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 10, 6
df_log = np.log(df_close)
moving_avg = df_log.rolling(12).mean()
std_dev = df_log.rolling(12).std()
plt.legend(loc='best')
plt.title('Moving Average')
plt.plot(std_dev, color ="black", label = "Standard Deviation")
plt.plot(moving_avg, color="red", label = "Mean")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
train_data, test_data = df_log[3:int(len(df_log)*0.9)], df_log[int(len(df_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing Prices')
plt.plot(df_log, 'green', label='Train data')
plt.plot(test_data, 'blue', label='Test data')
plt.legend()

# %%
model_autoARIMA = auto_arima(train_data, start_p=0, start_q=0,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
print(model_autoARIMA.summary())
model_autoARIMA.plot_diagnostics(figsize=(15,8))
plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=3178805.448, Time=8.25 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=21.12 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=inf, Time=48.42 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-2108961.755, Time=30.58 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=185.49 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=-2108985.670, Time=53.62 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1703515.246, Time=94.89 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=-2109002.094, Time=27.03 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=-2109019.873, Time=27.45 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=-2108945.598, Time=236.88 sec
#  ARIMA(3,0,3)(0,0,0)[0]             : AIC=-2109038.144, Time=59.66 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=-2109039.265, Time=48.10 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=-2109038.594, Time=48.17 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=-2109329.250, Time=267.72 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=-2109379.390, Time=57.11 sec
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 model_autoARIMA = auto_arima(train_data, start_p=0, start_q=0,
#       2                       test='adf',       # use adftest to find optimal 'd'
#       3                       max_p=3, max_q=3, # maximum p and q
#       4                       m=1,              # frequency of series
#       5                       d=None,           # let model determine 'd'
#       6                       seasonal=False,   # No Seasonality
#       7                       start_P=0,
#       8                       D=0,
#       9                       trace=True,
#      10                       error_action='ignore',
#      11                       suppress_warnings=True,
#      12                       stepwise=True)
#      13 print(model_autoARIMA.summary())
#      14 model_autoARIMA.plot_diagnostics(figsize=(15,8))
#
# File D:\Ananconda\envs\myenv\lib\site-packages\pmdarima\arima\auto.py:701, in auto_arima(y, X, start_p, d, start_q, max_p, max_d, max_q, start_P, D, start_Q, max_P, max_D, max_Q, max_order, m, seasonal, stationary, information_criterion, alpha, test, seasonal_test, stepwise, n_jobs, start_params, trend, method, maxiter, offset_test_args, seasonal_test_args, suppress_warnings, error_action, trace, random, random_state, n_fits, return_valid_fits, out_of_sample_size, scoring, scoring_args, with_intercept, sarimax_kwargs, **fit_args)
#     669     # init the stepwise model wrapper
#     670     search = solvers._StepwiseFitWrapper(
#     671         y,
#     672         X=X,
#    (...)
#     698         **sarimax_kwargs,
#     699     )
# --> 701 sorted_res = search.solve()
#     702 return _return_wrapper(sorted_res, return_valid_fits, start, trace)
#
# File D:\Ananconda\envs\myenv\lib\site-packages\pmdarima\arima\_auto_solvers.py:387, in _StepwiseFitWrapper.solve(self)
#     382     P += 1
#     383     continue
#     385 if p > 0 and \
#     386         self.k < self.max_k and \
# --> 387         self._do_fit((p - 1, d, q), (P, D, Q, m)):
#     388     p -= 1
#     389     continue
#
# File D:\Ananconda\envs\myenv\lib\site-packages\pmdarima\arima\_auto_solvers.py:235, in _StepwiseFitWrapper._do_fit(self, order, seasonal_order, constant)
#     230 if (order, seasonal_order, constant) not in self.results_dict:
#     231
#     232     # increment the number of fits
#     233     self.k += 1
# --> 235     fit, fit_time, new_ic = self._fit_arima(
#     236         order=order,
#     237         seasonal_order=seasonal_order,
#     238         with_intercept=constant)
#     240     # use the orders as a key to be hashed for
#     241     # the dictionary (pointing to fit)
#     242     self.results_dict[(order, seasonal_order, constant)] = fit
#
# File D:\Ananconda\envs\myenv\lib\site-packages\pmdarima\arima\_auto_solvers.py:508, in _fit_candidate_model(y, X, order, seasonal_order, start_params, trend, method, maxiter, fit_params, suppress_warnings, trace, error_action, out_of_sample_size, scoring, scoring_args, with_intercept, information_criterion, **kwargs)
#     500 fit = ARIMA(order=order, seasonal_order=seasonal_order,
#     501             start_params=start_params, trend=trend, method=method,
#     502             maxiter=maxiter, suppress_warnings=suppress_warnings,
#     503             out_of_sample_size=out_of_sample_size, scoring=scoring,
#     504             scoring_args=scoring_args,
#     505             with_intercept=with_intercept, **kwargs)
#     507 try:
# --> 508     fit.fit(y, X=X, **fit_params)
#     510 # for non-stationarity errors or singular matrices, return None
#     511 except (LinAlgError, ValueError) as v:
#
# File D:\Ananconda\envs\myenv\lib\site-packages\pmdarima\arima\arima.py:603, in ARIMA.fit(self, y, X, **fit_args)
#     600         X = safe_indexing(X, slice(0, n_exog - cv))
#     602 # Internal call
# --> 603 self._fit(y, X, **fit_args)
#     605 # now make a forecast if we're validating to compute the
#     606 # out-of-sample score
#     607 if cv_samples is not None:
#     608     # get the predictions (use self.predict, which calls forecast
#     609     # from statsmodels internally)
#
# File D:\Ananconda\envs\myenv\lib\site-packages\pmdarima\arima\arima.py:524, in ARIMA._fit(self, y, X, **fit_args)
#     522     with warnings.catch_warnings(record=False):
#     523         warnings.simplefilter('ignore')
# --> 524         fit, self.arima_res_ = _fit_wrapper()
#     525 else:
#     526     fit, self.arima_res_ = _fit_wrapper()
#
# File D:\Ananconda\envs\myenv\lib\site-packages\pmdarima\arima\arima.py:510, in ARIMA._fit.<locals>._fit_wrapper()
#     507 _maxiter = fit_args.pop("maxiter", _maxiter)
#     509 disp = fit_args.pop("disp", 0)
# --> 510 fitted = arima.fit(
#     511     start_params=start_params,
#     512     method=method,
#     513     maxiter=_maxiter,
#     514     disp=disp,
#     515     **fit_args,
#     516 )
#     518 return arima, fitted
#
# File D:\Ananconda\envs\myenv\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:728, in MLEModel.fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     726 else:
#     727     func = self.smooth
# --> 728 res = func(mlefit.params, transformed=False, includes_fixed=False,
#     729            cov_type=cov_type, cov_kwds=cov_kwds)
#     731 res.mlefit = mlefit
#     732 res.mle_retvals = mlefit.mle_retvals
#
# File D:\Ananconda\envs\myenv\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:886, in MLEModel.smooth(self, params, transformed, includes_fixed, complex_step, cov_type, cov_kwds, return_ssm, results_class, results_wrapper_class, **kwargs)
#     883     kwargs['inversion_method'] = INVERT_UNIVARIATE | SOLVE_LU
#     885 # Get the state space output
# --> 886 result = self.ssm.smooth(complex_step=complex_step, **kwargs)
#     888 # Wrap in a results object
#     889 return self._wrap_results(params, result, return_ssm, cov_type,
#     890                           cov_kwds, results_class,
#     891                           results_wrapper_class)
#
# File D:\Ananconda\envs\myenv\lib\site-packages\statsmodels\tsa\statespace\kalman_smoother.py:403, in KalmanSmoother.smooth(self, smoother_output, smooth_method, results, run_filter, prefix, complex_step, update_representation, update_filter, update_smoother, **kwargs)
#     377 """
#     378 Apply the Kalman smoother to the statespace model.
#     379
#    (...)
#     399 SmootherResults object
#     400 """
#     402 # Run the filter
# --> 403 kfilter = self._filter(**kwargs)
#     405 # Create the results object
#     406 results = self.results_class(self)
#
# File D:\Ananconda\envs\myenv\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py:913, in KalmanFilter._filter(self, filter_method, inversion_method, stability_method, conserve_memory, filter_timing, tolerance, loglikelihood_burn, complex_step)
#     907 def _filter(self, filter_method=None, inversion_method=None,
#     908             stability_method=None, conserve_memory=None,
#     909             filter_timing=None, tolerance=None, loglikelihood_burn=None,
#     910             complex_step=False):
#     911     # Initialize the filter
#     912     prefix, dtype, create_filter, create_statespace = (
# --> 913         self._initialize_filter(
#     914             filter_method, inversion_method, stability_method,
#     915             conserve_memory, filter_timing, tolerance, loglikelihood_burn
#     916         )
#     917     )
#     918     kfilter = self._kalman_filters[prefix]
#     920     # Initialize the state
#
# File D:\Ananconda\envs\myenv\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py:501, in KalmanFilter._initialize_filter(self, filter_method, inversion_method, stability_method, conserve_memory, tolerance, filter_timing, loglikelihood_burn)
#     499     # Setup the filter
#     500     cls = self.prefix_kalman_filter_map[prefix]
# --> 501     self._kalman_filters[prefix] = cls(
#     502         self._statespaces[prefix], filter_method, inversion_method,
#     503         stability_method, conserve_memory, filter_timing, tolerance,
#     504         loglikelihood_burn
#     505     )
#     506 # Otherwise, update the filter parameters
#     507 else:
#     508     kalman_filter = self._kalman_filters[prefix]
#
# File statsmodels\tsa\statespace\_kalman_filter.pyx:1720, in statsmodels.tsa.statespace._kalman_filter.dKalmanFilter.__init__()
#
# File statsmodels\tsa\statespace\_kalman_filter.pyx:2131, in statsmodels.tsa.statespace._kalman_filter.dKalmanFilter.set_filter_method()
#
# File statsmodels\tsa\statespace\_kalman_filter.pyx:1911, in statsmodels.tsa.statespace._kalman_filter.dKalmanFilter.allocate_arrays()
#
# MemoryError: Unable to allocate 68.0 MiB for an array with shape (4, 4, 557134) and data type float64

# %%
model = ARIMA(train_data, order=(1,1,2))  
fitted = model.fit(disp=-1)  
print(fitted.summary())
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 model = ARIMA(train_data, order=(1,1,2))
#       2 fitted = model.fit(disp=-1)
#       3 print(fitted.summary())
#
# File D:\Ananconda\envs\myenv\lib\site-packages\statsmodels\tsa\arima_model.py:45, in ARIMA.__init__(self, *args, **kwargs)
#      44 def __init__(self, *args, **kwargs):
# ---> 45     super().__init__(*args, **kwargs)
#
# File D:\Ananconda\envs\myenv\lib\site-packages\statsmodels\tsa\arima_model.py:29, in ARMA.__init__(self, *args, **kwargs)
#      28 def __init__(self, *args, **kwargs):
# ---> 29     raise NotImplementedError(ARIMA_DEPRECATION_ERROR)
#
# NotImplementedError:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been removed in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and statsmodels.tsa.SARIMAX.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained. It also offers alternative specialized
# parameter estimators.

# %%
fc, se, conf = fitted.forecast(321, alpha=0.05)  # 95% conf
# Make as pandas series
fc_series = pd.Series(fc, index=test_data.index)
lower_series = pd.Series(conf[:, 0], index=test_data.index)
upper_series = pd.Series(conf[:, 1], index=test_data.index)
# Plot
plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training data')
plt.plot(test_data, color = 'blue', label='Actual Stock Price')
plt.plot(fc_series, color = 'orange',label='Predicted Stock Price')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.10)
plt.title(' Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel(' Stock Price')
plt.legend(loc='upper left', fontsize=8)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 fc, se, conf = fitted.forecast(321, alpha=0.05)  # 95% conf
#       2 # Make as pandas series
#       3 fc_series = pd.Series(fc, index=test_data.index)
#
# NameError: name 'fitted' is not defined

# %%
# report performance
mse = mean_squared_error(test_data, fc)
print('MSE: '+str(mse))
mae = mean_absolute_error(test_data, fc)
print('MAE: '+str(mae))
rmse = math.sqrt(mean_squared_error(test_data, fc))
print('RMSE: '+str(rmse))
mape = np.mean(np.abs(fc - test_data)/np.abs(test_data))
print('MAPE: '+str(mape))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # report performance
# ----> 2 mse = mean_squared_error(test_data, fc)
#       3 print('MSE: '+str(mse))
#       4 mae = mean_absolute_error(test_data, fc)
#
# NameError: name 'mean_squared_error' is not defined
